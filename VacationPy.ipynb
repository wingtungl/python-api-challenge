# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      atbara  17.7022   33.9864     26.44        50          58
# 1        1   haparanda  65.8355   24.1368     -3.97        97          99
# 2        2      vuktyl  63.8567   57.3094    -12.16        93         100
# 3        3  vila velha -20.3297  -40.2925     23.97        71          75
# 4        4      la foa -21.7108  165.8276     25.32        58          89
#
#    Wind Speed Country        Date
# 0        3.86      SD  1700957217
# 1        1.75      SE  1700957217
# 2        1.34      RU  1700957218
# 3        5.14      BR  1700957218
# 4        3.30      NC  1700957219

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
map_plot_1 = city_data_df.hvplot.points('Lng','Lat',geo = True,size = "humidity",tiles = "OSM",color = "City")

map_plot_1
# Out:
# WARNING:param.GeoPointPlot02629: Specified size dim transform (np.sqrt(dim('humidity'))*1) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#Criteria:
    #A max temperature lower than 27 degrees but higher than 15
    #Wind speed less than 5 m/s
    #Cloudiness less than 5
criteria_df = city_data_df.loc[(city_data_df['Max Temp']<27)&
                               (city_data_df['Max Temp']>15)&
                               (city_data_df['Wind Speed']<5)&
                               (city_data_df['Cloudiness']<5),:]

# Drop any rows with null values
criteria_df.dropna()

# Display sample data
criteria_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 50        50              taoudenni  22.6783   -3.9836     17.65        21
# 86        86    san luis de la loma  17.2706 -100.8939     26.10        77
# 118      118                  kiffa  16.6166  -11.4045     22.92        15
# 124      124                   atar  20.5169  -13.0499     19.57        19
# 135      135        piton saint-leu -21.2196   55.3151     20.06        68
# 159      159               tolanaro -25.0319   46.9987     22.39        91
# 180      180                 lompoc  34.6391 -120.4579     19.32        57
# 183      183                 haimen  23.1935  116.6142     17.93        75
# 188      188             swakopmund -22.6833   14.5333     16.10        88
# 212      212                 dabhol  17.6000   73.1667     23.69        83
# 267      267             walvis bay -22.9575   14.5053     16.16        82
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = criteria_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
hotel_df

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 50               taoudenni      ML  22.6783   -3.9836        21
# 86     san luis de la loma      MX  17.2706 -100.8939        77
# 118                  kiffa      MR  16.6166  -11.4045        15
# 124                   atar      MR  20.5169  -13.0499        19
# 135        piton saint-leu      RE -21.2196   55.3151        68
# 159               tolanaro      MG -25.0319   46.9987        91
# 180                 lompoc      US  34.6391 -120.4579        57
# 183                 haimen      CN  23.1935  116.6142        75
# 188             swakopmund     NaN -22.6833   14.5333        88
# 212                 dabhol      IN  17.6000   73.1667        83
# 267             walvis bay     NaN -22.9575   14.5053        82
# 271              springbok      ZA -29.6643   17.8865        29
# 293              patterson      US  37.4716 -121.1297        42
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
# Set the parameters for the type of place
radius = 10000
categories = "accommodation"

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitute = row["Lat"]
    longitute = row["Lng"]
    
    # set up a parameters dictionary
    params = {
        "categories":categories,
        "apiKey":geoapify_key  
    }
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitute},{latitute},{radius}"
    params["bias"] = f"proximity:{longitute},{latitute}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"

    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# taoudenni - nearest hotel: Taoudeni
# san luis de la loma - nearest hotel: No hotel found
# kiffa - nearest hotel: فندق كيفة
# atar - nearest hotel: دوم سنيبا
# piton saint-leu - nearest hotel: Les Lataniers
# tolanaro - nearest hotel: Hôtel Mahavokey
# lompoc - nearest hotel: Alano Club
# haimen - nearest hotel: No hotel found
# swakopmund - nearest hotel: Organic Square Guesthouse 2
# dabhol - nearest hotel: Virgin Winds
# walvis bay - nearest hotel: Atlantic
# springbok - nearest hotel: Mountain View Guest House
# patterson - nearest hotel: Hampton Inn & Suites
# tsiombe - nearest hotel: No hotel found
# newman - nearest hotel: Hamlet Motel
# la ligua - nearest hotel: Hotel Anchimallen
# coahuayana de hidalgo - nearest hotel: No hotel found
# adelia maria - nearest hotel: Hostal Los Olmos
# broken hill - nearest hotel: Sturt Motel
# tupancireta - nearest hotel: Hotel Cassino
# timbuktu - nearest hotel: Hotel La Maison
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
map_plot_2 = hotel_df.hvplot.points('Lng','Lat',geo = True,tiles = "OSM",color = "City",frame_width = 650,frame_height = 500,hover_cols='all')

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,index,Country,Humidity,Hotel Name)
